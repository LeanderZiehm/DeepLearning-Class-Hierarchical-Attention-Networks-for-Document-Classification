# %%
import pandas as pd

true = pd.read_csv('/home/user/workspace/DeepLearning-Class-Hierarchical-Attention-Networks-for-Document-Classification/data/trainset.csv')
true
# Out:
#                                                    title  \
# 0      SocGen says no wrongdoing in handling of Natio...
# 1      North Carolina governor concedes election to D...
# 2      TRUMP FEVER! W. VA Dem Senator Says He Won’t V...
# 3      New York vows to sue Trump over immigrant chil...
# 4      Orlando killer expressed support for multiple ...
# ...                                                  ...
# 35913  N KOREA JUST REVEALED Plans To Unleash An Unim...
# 35914  Trump to meet with top executives on wireless ...
# 35915   WATCH: Obama Goes BEAST MODE On CNN Anchor Fo...
# 35916  YIKES! Hillary Still Needs Help Walking On Sta...
# 35917  China's top paper warns party officials agains...
#
#                                                     text       subject  \
# 0      PARIS (Reuters) - French bank Societe Generale...     worldnews
# 1      WINSTON-SALEM, N.C. (Reuters) - North Carolina...  politicsNews
# ...

# %%
firstText = true['text'].iloc[0]
firstText
with open('temp/firstText.txt', 'w') as f:
    f.write(firstText)
    f.close()
